# %%
# %pylab notebook
import os, sys

sys.path.append('/Users/alexisdevitre/Documents/code/hts-irradiation/')

import hts_fitting as ht, hts_showcase as sc, hts_dosecalculations as dose
from scipy.interpolate import interp1d
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
def estimate_step_dose(data, t0, t1, t2, t3, vb=False):
    d = data[((t0 <= data.time_s) & (data.time_s < t1)) | ((t2 <= data.time_s) & (data.time_s < t3))]
    x = np.arange(d.time_s.min(), d.time_s.max(), 1)
    y = interp1d(d.time_s, d.ibeam_nA)(x)
    if vb:
        fig, ax = plt.subplots()
        ax.plot(x, y, marker='o', linestyle='None')
        ax.plot(d.time_s, d.ibeam_nA, marker='+', color='k')
    return np.trapz(y, dx=1)

# %%
data = dose.loadBeamCurrent(ibpath, sname)
t0, t1, t2, t3 = 136, 147, 179, 194

estimate_step_dose(data, t0, t1, t2, t3, vb=True)
# Out:
# <img src="data:image/png;base64,..." width="800">
# 1671.2935

# %%
ibpath = '/Users/alexisdevitre/MIT Dropbox/Alexis Devitre/2020 PhD/Research/data/Fluence data/Proton_2025_03_27_Alexis_FFJ51.xlsx'
sname = 'beamon'
data = dose.loadBeamCurrent(ibpath, sname)
data
# Out:
#            time_datetime  time_s  ibeam_nA
# 0    2025-03-27 00:37:07     1.0     1.098
# 1    2025-03-27 00:37:08     2.0     1.096
# 2    2025-03-27 00:37:09     3.0     0.918
# 3    2025-03-27 00:37:10     4.0     0.896
# 4    2025-03-27 00:37:11     5.0     0.860
# ...                  ...     ...       ...
# 3054                 NaT     NaN       NaN
# 3055                 NaT     NaN       NaN
# 3056                 NaT     NaN       NaN
# 3057                 NaT     NaN       NaN
# 3058                 NaT     NaN       NaN
#
# [3059 rows x 3 columns]
