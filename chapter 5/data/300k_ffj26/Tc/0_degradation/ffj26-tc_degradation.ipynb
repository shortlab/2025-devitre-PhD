# %%
# %pylab notebook

import os, sys, warnings, pandas as pd
sys.path.append('/Users/alexisdevitre/Documents/code/hts-irradiation/')

import hts_fitting as hts
import hts_showcase as sc

#from scipy.optimize import OptimizeWarning

#warnings.simplefilter("ignore", RuntimeWarning)
#warnings.simplefilter("ignore", OptimizeWarning)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
path = './'
fpaths = [path+f for f in np.sort(os.listdir(path)) if 'Tc' in f]

for fpath in fpaths:
    print(fpath)

hts.fitTcMeasurement(fpaths[3], vb=True)
# Out:
# ./Tc_2023-11-10_17-35-53394703_ffj26-step00-dn-kapton.txt
# ./Tc_2023-11-10_17-48-22870126_ffj26-step00-up-kapton.txt
# ./Tc_2023-11-11_00-44-17677954_ffj26-step01-up-kapton.txt
# ./Tc_2023-11-11_05-46-48149581_ffj26-step02-dn-kapton.txt
# <img src="data:image/png;base64,..." width="900">
# 80.02667641076411

# %%
# %debug
# Out:
# > /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py(3655)get_loc()
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# ipdb> up
# > /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/pandas/core/series.py(1116)_get_value()
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# ipdb> up
# > /Users/alexisdevitre/anaconda3/lib/python3.11/site-packages/pandas/core/series.py(1007)__getitem__()
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# ipdb> up
# > /Users/alexisdevitre/Documents/code/hts-irradiation/hts_fitting.py(348)fitTcMeasurement()
#     346     temperature, vdT = rdata.sampleT[cut], vdT[cut]
#     347
# --> 348     popt, pcov = curve_fit(ff.gaussian, temperature, vdT, p0=[2, rdata.sampleT[(rdata.voltage-rdata.voltage.max()/2).abs().argmin()], 1])
#     349     ysmooth = ff.gaussian(xsmooth, *popt)
#     350     tc = xsmooth[np.argmax(ysmooth)]
#
# ipdb> rdata.voltage.max()/2
# 0.014713362320000001
# ipdb> (rdata.voltage-rdata.voltage.max()/2).abs().argmin()
# 22
# ipdb> exit
