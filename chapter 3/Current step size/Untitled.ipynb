# %%
# %pylab notebook
import os, sys
sys.path.append('/Users/alexisdevitre/Documents/code/hts-irradiation/')
import hts_fitting as hts
import hts_fitfunctions as ff
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.arange(0, 15, 0.6)
y_n20 = ff.powerLaw(x, 10, 20)*1e6
y_n30 = ff.powerLaw(x, 10, 30)*1e6
y_n40 = ff.powerLaw(x, 10, 40)*1e6

fig, ax = plt.subplots()

ax.plot(x, y_n20, marker='o')
ax.plot(x, y_n30, marker='o')
ax.plot(x, y_n40, marker='o')

ax.axhline(0.2, linestyle='--')
ax.axhline(30, linestyle='--')

ax.set_ylim(0, 100)
# Out:
# <img src="data:image/png;base64,..." width="800">
# (0.0, 100.0)
